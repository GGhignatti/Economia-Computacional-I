# %% [markdown]
# # Processamento de dados

# %%
## Processamento lógico

### Definição do tipo lógico

Logico = {True, False}

# %%
### Operações lógicas
1. Operação conjunção
2. Operação disjunção
3. Operação negação
